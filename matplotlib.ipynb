# %% [markdown]
# <a href="https://colab.research.google.com/github/ro-prates/data_science/blob/master/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
x = np.linspace(0, 5, 11)
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y = x * x
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x, y, color='black')
plt.xlabel('Eixo x')
plt.ylabel('Eixo y')
plt.title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
plt.subplot(1, 2, 1)
plt.plot(x, y, 'r--')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'g*-')

# %%
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.2, 0.3, 0.3, 0.3])
axes1.plot(x, y)
axes1.set_xlabel('Eixo x')
axes1.set_title('Título')
axes2.plot(y, x)

# %%
fig, ax = plt.subplots()
ax.plot(x, x**3, 'b--')
ax.plot(x, x**4, 'g--')
ax.set_xlabel('Eixo x')
ax.set_ylabel('Eixo y')
ax.set_title('Título')
# Out:
# Text(0.5, 1.0, 'Título')

# %%
fig, ax = plt.subplots(nrows=1, ncols=2)

# %%
ax[0].plot(x, y, 'b')
ax[0].set_title('Título')

ax[1].plot(x, y, 'b')
ax[1].set_title('Título')
fig

# %%
fig, ax = plt.subplots(nrows=5, ncols=5)
plt.tight_layout()

# %%
fig = plt.figure(figsize=(8, 4), dpi=100)

# %%
fig, axes = plt.subplots(figsize=(8, 10))
axes.plot(x, y, 'black', label='Dados 1')
axes.plot(y, x, 'red', label='Dados 2')
axes.set_title('Título')
axes.legend(loc=0)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ax.plot(x, x**2, 'black', linewidth = 10)
ax.plot(x, x**3, 'red', linewidth = 10)

ax.set_xlim([0,2])
ax.set_ylim([0,10])
# Out:
# (0.0, 10.0)
